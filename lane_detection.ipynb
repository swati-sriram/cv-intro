# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import lane_detection
import lane_following

# %%
img = cv2.imread('test_img_2.png')

# %%
plt.imshow(img)

# %%
lines = lane_detection.detect_lines(img, 450, 500, 5)
print(lines)
lane_detection.draw_lines(img, lines)
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 lines = lane_detection.detect_lines(img, 450, 500, 5)
#       2 print(lines)
# ----> 3 lane_detection.draw_lines(img, lines)
#
# File ~/cv-intro/lane_detection.py:21, in draw_lines(img, lines, color)
#      20 def draw_lines(img:str, lines:np.array, color:tuple = (0,255,0)):
# ---> 21     for line in lines:
#      22         x1, y1, x2, y2 = line[0]
#      23         cv2.line(img, (x1, y1), (x2, y2), (color), 2)
#
# TypeError: 'NoneType' object is not iterable
